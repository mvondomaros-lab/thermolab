# %% [markdown]
# # Part 3: Acid–Base Thermochemistry and Solvent Effects
#
# ## Introduction
#
# In this notebook you will apply the PySCF RRHO workflow from **Part 1** to an **acid–base equilibrium**
# and examine how an implicit solvent model (PCM water) changes the result.
#
# We use the deprotonation of acetic acid, written in a way that avoids an explicit free proton:
#
# $$
# \mathrm{CH_3COOH + H_2O \rightleftharpoons CH_3COO^- + H_3O^+}.
# $$
#
# ## Learning goals
#
# After completing Part 3, you should be able to:
#
# - build simple molecular starting geometries from SMILES strings using RDKit,
# - compute RRHO Gibbs free energies for neutral and charged species,
# - assemble $\Delta_r G^\circ$ for an acid–base reaction and convert it to an equilibrium constant, and
# - estimate $\mathrm{pK_a}$ values and explain the role of the water standard-state correction and PCM.
#
# :::{note} Conventions
# Unless stated otherwise, we use $T = 298.15\,\mathrm{K}$ and $P = 1\,\mathrm{bar}$.
# Pressure is provided to PySCF in Pa, so $1\,\mathrm{bar} = 100000\,\mathrm{Pa}$.
# :::

# %% [markdown]
# ## From $\Delta_r G^\circ$ to $\mathrm{pK_a}$
#
# In this notebook we evaluate the reaction
#
# $$
# \mathrm{HA + H_2O \rightleftharpoons A^- + H_3O^+}
# $$
#
# and compute its standard reaction Gibbs free energy, $\Delta_r G^\circ$, from RRHO free energies.
#
# Experimental $\mathrm{pK_a}$ values are defined for dissociation in *water as solvent*, where the activity
# of liquid water is taken as approximately unity ($a_{\mathrm{H_2O}}\approx 1$):
#
# $$
# K_a = \frac{a_{\mathrm{A^-}}\,a_{\mathrm{H_3O^+}}}{a_{\mathrm{HA}}}.
# $$
#
# If we instead define an equilibrium constant for the reaction that **includes water as a reactant**,
# then (to a good approximation near room temperature)
#
# $$
# K_a \approx K_{\mathrm{rxn}}\,[\mathrm{H_2O}],
# \qquad [\mathrm{H_2O}]\approx 55.5\ \mathrm{mol\,L^{-1}}.
# $$
#
# Equivalently,
#
# $$
# \Delta G^\circ_a \approx \Delta_r G^\circ - RT\ln(55.5),
# \qquad
# \mathrm{pK_a} = \frac{\Delta G^\circ_a}{2.303\,RT}.
# $$
#
# :::{admonition} What we will report
# We compute **both** (i) $K_{\mathrm{rxn}}$ from $\Delta_r G^\circ$ and (ii) an estimated $\mathrm{pK_a}$
# using the water-concentration correction above.
# :::

# %% [markdown]
# ## Setup
#
# Run the next cell once to import modules used throughout the notebook.

# %%
import math

from pyscf import dft, gto
from pyscf.geomopt.geometric_solver import optimize
from pyscf.hessian import thermo
from rdkit import Chem
from rdkit.Chem import AllChem

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

import patch

# %% [markdown]
# ## Helper: RRHO thermochemistry for one molecule
#
# The function below reproduces the Part 1 workflow for a single species:
#
# 1. geometry optimization (DFT),
# 2. Hessian and harmonic frequency analysis, and
# 3. RRHO thermochemistry via `thermo.thermo(...)`.
#
# It returns the `thermo_info` dictionary. In this notebook we extract total Gibbs free energies from
# the key `"G_tot"` (stored as a `(value, unit)` pair).

# %%
def compute_thermo_for_molecule(
    mol, T=298.15, P=100000.0, use_pcm=False, eps_water=78.3553
):
    """Geometry optimization + RRHO thermochemistry for one molecule."""

    # --- Geometry optimization ---
    mf = dft.RKS(mol).density_fit()
    mf.xc = "wb97x"
    mf.disp = "d4"
    mf.grids.level = 4
    mf.conv_tol = 1e-9

    if use_pcm:
        mf = mf.PCM()
        mf.with_solvent.eps = eps_water

    mol_opt = optimize(mf)

    # --- Single-point + Hessian on optimized geometry (same method/settings) ---
    mf_opt = dft.RKS(mol_opt).density_fit()
    mf_opt.xc = "wb97x"
    mf_opt.disp = "d4"
    mf_opt.grids.level = 4
    mf_opt.conv_tol = 1e-9

    if use_pcm:
        mf_opt = mf_opt.PCM()
        mf_opt.with_solvent.eps = eps_water

    _ = mf_opt.kernel()

    hess_opt = mf_opt.Hessian().kernel()
    freq_info = thermo.harmonic_analysis(mol_opt, hess_opt)

    return thermo.thermo(mf_opt, freq_info["freq_au"], T, P)

# %% [markdown]
# ## Building molecules from SMILES with RDKit
#
# For this project you can generate initial geometries directly from **SMILES** strings.
#
# A SMILES string encodes connectivity and (when needed) formal charges. For the species used here:
#
# - Acetic acid (HA): `CC(=O)O`
# - Acetate (A⁻): `CC(=O)[O-]`
# - Water: `O`
# - Hydronium: `[OH3+]`
#
# RDKit can generate a reasonable 3D starting structure via distance-geometry embedding. PySCF will then
# optimize the geometry at the chosen level of theory.
#
# :::{tip} Why this is sufficient
# These are small molecules with simple bonding; a plain 3D embed is typically adequate as an initial guess.
# If you encounter convergence issues, you can re-run the embed with a different random seed.
# :::

# %%
def mol_from_smiles(
    smiles: str,
    charge: int,
    basis: str = "def2-SVPD",
    seed: int = 1,
    verbose: int = 0,
):
    """Create a PySCF Mole object from a SMILES string using RDKit 3D embedding."""
    rdmol = Chem.AddHs(Chem.MolFromSmiles(smiles))

    params = AllChem.ETKDGv3()
    params.randomSeed = int(seed)
    ok = AllChem.EmbedMolecule(rdmol, params)
    if ok != 0:
        raise RuntimeError(f"RDKit embedding failed for SMILES: {smiles}")

    conf = rdmol.GetConformer()
    atom_lines = []
    for atom in rdmol.GetAtoms():
        pos = conf.GetAtomPosition(atom.GetIdx())
        atom_lines.append(f"{atom.GetSymbol()} {pos.x:.8f} {pos.y:.8f} {pos.z:.8f}")

    atom_block = "\n".join(atom_lines)
    return gto.M(atom=atom_block, basis=basis, charge=charge, verbose=verbose)

# %% [markdown]
# ## Define the species
#
# We model acetic acid deprotonation with water as base:
#
# $$
# \mathrm{CH_3COOH + H_2O \rightleftharpoons CH_3COO^- + H_3O^+}.
# $$
#
# Run the next cells to build all four species from SMILES.

# %%
# Example: acetic acid
acoh = mol_from_smiles("CC(=O)O", charge=0)
print(acoh.atom)
# Out:
# C -0.97323403 -0.07999454 0.01135459
# C 0.45339470 0.27870779 -0.09536990
# O 0.78877976 1.48415321 0.15479113
# O 1.46399139 -0.57973789 -0.44411547
# H -1.59072226 0.82026559 -0.12593399
# H -1.21685718 -0.44346409 1.04969537
# H -1.26670743 -0.91595669 -0.65147734
# H 2.34135505 -0.56397339 0.10105562

# %%
aco_minus = mol_from_smiles("CC(=O)[O-]", charge=-1)
h2o = mol_from_smiles("O", charge=0)
h3o_plus = mol_from_smiles("[OH3+]", charge=1)

# %% [markdown]
# ## Gas-phase reaction thermochemistry
#
# 1. Compute RRHO thermochemistry in the gas phase (`use_pcm=False`) for each species.
# 2. Extract $G^\circ$ from each `thermo_info` dictionary using the key `"G_tot"`.
# 3. Form $\Delta_r G^\circ$ and convert it to $K_{\mathrm{rxn}}$.
# 4. Apply the water-concentration correction to estimate $\mathrm{pK_a}$.

# %%
T = 298.15  # K
P = 100000.0  # Pa (1 bar)
R = 0.008314462618  # kkJ mol^-1 K^-1
hartree_to_kjmol = 2625.499748
G_key = "G_tot"
water_conc = 55.5  # mol/L

thermo_acoh_gas = compute_thermo_for_molecule(acoh, T=T, P=P, use_pcm=False)
thermo_aco_gas = compute_thermo_for_molecule(aco_minus, T=T, P=P, use_pcm=False)
thermo_h2o_gas = compute_thermo_for_molecule(h2o, T=T, P=P, use_pcm=False)
thermo_h3o_gas = compute_thermo_for_molecule(h3o_plus, T=T, P=P, use_pcm=False)

G_acoh_gas, _ = thermo_acoh_gas[G_key]
G_aco_gas, _ = thermo_aco_gas[G_key]
G_h2o_gas, _ = thermo_h2o_gas[G_key]
G_h3o_gas, _ = thermo_h3o_gas[G_key]

delta_G_gas = (G_aco_gas + G_h3o_gas) - (G_acoh_gas + G_h2o_gas)
delta_G_gas_kJmol = delta_G_gas * hartree_to_kjmol

K_rxn_gas = math.exp(-delta_G_gas_kJmol / (R * T))
pK_rxn_gas = -math.log10(K_rxn_gas)
pKa_gas = pK_rxn_gas - math.log10(water_conc)

print(f"Gas phase: Δ_r G° = {delta_G_gas_kJmol:.2f} kJ/mol")
print(f"Gas phase: K_rxn°  = {K_rxn_gas:.3e}")
print(f"Gas phase: pK_rxn  = {pK_rxn_gas:.2f}")
print(f"Gas phase: pKa ≈ {pKa_gas:.2f}")
# Out:
# geometric-optimize called with the following command line:
# /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/ipykernel_launcher.py -f /Users/mvondomaros/Library/Jupyter/runtime/kernel-560a9676-9c47-4ab6-b4dd-10595e1cfe53.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
#           ##      .%%%%%%/      (%%%%%%,                  ,******      /)))))
#         %%%%%%      .%%%%%%#      *%%%%%%,    ,/////.       ******      ))))))
#       #%      %%      .%%%%%%/      *%%%%%%,  ////////,      *****/     ,)))))
#     #%%  %%%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#   #%%%%.      %%%%%#      /%%%%%%*      #%%%%%%   /////)     ******      ))))),
#     #%%%%##%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#       ##     %%%      .%%%%%%/      *%%%%%%,  ////////.      *****/     ,)))))
#         #%%%%#      /%%%%%%/      (%%%%%%      /)/)//       ******      ))))))
#           ##      .%%%%%%/      (%%%%%%,                  *******      ))))))
#                 .%%%%%%/      *%%%%%%,  **.             /*******      .))))))
#               *%%%%%%/      (%%%%%%   ********/*..,*/*********       *))))))
#                 #%%/      (%%%%%%,    *********************/        )))))))
#                         *%%%%%%,         ,**************/         ,))))))/
#                       (%%%%%%   ()                              ))))))))
#                       #%%%%,  ())))))                        ,)))))))),
#                         #,    ())))))))))                ,)))))))))).
#                                  ()))))))))))))))))))))))))))))))/
#                                     ())))))))))))))))))))))))).
#                                          ())))))))))))))),
#
# -=#  geomeTRIC started. Version: 1.1  #=-
# Current date and time: 2026-01-30 14:58:16
# #========================================================#
# #|     Arguments passed to driver run_optimizer():      |#
# #========================================================#
# customengine              <pyscf.geomopt.geometric_solver.PySCFEngine object at 0x1611a1d30>
# input                     /var/folders/zr/f87d28w54h3djm8md3cct4300000gn/T/tmphimf70ix/d5289443-9d6f-4eb8-b2c7-514b8de51209
# logIni                    /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/pyscf/geomopt/log.ini
# maxiter                   100
# ----------------------------------------------------------
# Custom engine selected.
# Bonds will be generated from interatomic distances less than 1.20 times sum of covalent radii
# 24 internal coordinates being used (instead of 24 Cartesians)
# Internal coordinate system (atoms numbered from 1):
# Distance 1-2
# Distance 1-5
# Distance 1-6
# Distance 1-7
# Distance 2-3
# Distance 2-4
# Distance 4-8
# Angle 2-1-5
# Angle 2-1-6
# Angle 2-1-7
# Angle 5-1-6
# Angle 5-1-7
# Angle 6-1-7
# Angle 1-2-4
# Angle 3-2-4
# Angle 2-4-8
# Out-of-Plane 2-1-3-4
# Dihedral 5-1-2-3
# Dihedral 5-1-2-4
# Dihedral 6-1-2-3
# Dihedral 6-1-2-4
# Dihedral 7-1-2-3
# Dihedral 7-1-2-4
# Dihedral 1-2-4-8
# Dihedral 3-2-4-8
# Translation-X 1-8
# Translation-Y 1-8
# Translation-Z 1-8
# Rotation-A 1-8
# Rotation-B 1-8
# Rotation-C 1-8
# <class 'geometric.internal.Distance'> : 7
# <class 'geometric.internal.Angle'> : 9
# <class 'geometric.internal.OutOfPlane'> : 1
# <class 'geometric.internal.Dihedral'> : 8
# <class 'geometric.internal.TranslationX'> : 1
# <class 'geometric.internal.TranslationY'> : 1
# <class 'geometric.internal.TranslationZ'> : 1
# <class 'geometric.internal.RotationA'> : 1
# <class 'geometric.internal.RotationB'> : 1
# <class 'geometric.internal.RotationC'> : 1
# > ===== Optimization Info: ====
# > Job type: Energy minimization
# > Maximum number of optimization cycles: 100
# > Initial / maximum trust radius (Angstrom): 0.100 / 0.300
# > Convergence Criteria:
# > Will converge when all 5 criteria are reached:
# >  |Delta-E| < 1.00e-06
# >  RMS-Grad  < 3.00e-04
# >  Max-Grad  < 4.50e-04
# >  RMS-Disp  < 1.20e-03
# >  Max-Disp  < 1.80e-03
# > === End Optimization Info ===
# Step    0 : Gradient = 6.461e-02/1.371e-01 (rms/max) Energy = -228.8465438247
# Hessian Eigenvalues: 2.30000e-02 2.30000e-02 2.58269e-02 ... 4.23171e-01 5.07698e-01 7.43264e-01
# Step    1 : Displace = 1.081e-01/1.855e-01 (rms/max) Trust = 1.000e-01 (=) Grad = 2.373e-02/4.733e-02 (rms/max) E (change) = -228.8684986697 (-2.195e-02) Quality = 0.983
# Hessian Eigenvalues: 2.17763e-02 2.30008e-02 2.58270e-02 ... 4.45145e-01 5.82262e-01 6.93408e-01
# Step    2 : Displace = 1.241e-01/2.223e-01 (rms/max) Trust = 1.414e-01 (+) Grad = 3.571e-02/6.401e-02 (rms/max) E (change) = -228.8718790567 (-3.380e-03) Quality = 0.298
# Hessian Eigenvalues: 1.50522e-02 2.30010e-02 2.58259e-02 ... 5.04878e-01 6.42516e-01 8.33387e-01
# Step    3 : Displace = 6.982e-02/1.200e-01 (rms/max) Trust = 1.414e-01 (=) Grad = 5.874e-03/1.418e-02 (rms/max) E (change) = -228.8788342948 (-6.955e-03) Quality = 0.894
# Hessian Eigenvalues: 1.61579e-02 2.30079e-02 2.58265e-02 ... 5.27734e-01 6.62505e-01 8.33130e-01
# Step    4 : Displace = 3.294e-02/5.439e-02 (rms/max) Trust = 2.000e-01 (+) Grad = 2.103e-03/3.898e-03 (rms/max) E (change) = -228.8791820118 (-3.477e-04) Quality = 0.689
# Hessian Eigenvalues: 2.02096e-02 2.26768e-02 2.61601e-02 ... 5.00178e-01 6.97988e-01 8.20046e-01
# Step    5 : Displace = 1.132e-02/2.264e-02 (rms/max) Trust = 2.000e-01 (=) Grad = 2.932e-04/5.555e-04 (rms/max) E (change) = -228.8792732207 (-9.121e-05) Quality = 1.066
# Hessian Eigenvalues: 1.82891e-02 2.29406e-02 2.69867e-02 ... 4.95816e-01 6.82110e-01 8.26837e-01
# Step    6 : Displace = 3.051e-03/4.468e-03 (rms/max) Trust = 2.828e-01 (+) Grad = 1.870e-04/3.158e-04 (rms/max) E (change) = -228.8792799911 (-6.770e-06) Quality = 1.712
# Hessian Eigenvalues: 3.08416e-03 2.26127e-02 2.87043e-02 ... 5.17584e-01 8.03086e-01 8.90236e-01
# Step    7 : Displace = 1.958e-02/3.058e-02 (rms/max) Trust = 3.000e-01 (+) Grad = 8.889e-04/1.555e-03 (rms/max) E (change) = -228.8793092441 (-2.925e-05) Quality = 1.482
# Hessian Eigenvalues: 1.02956e-03 2.27590e-02 2.94469e-02 ... 5.34050e-01 8.04880e-01 1.11915e+00
# Step    8 : Displace = 4.120e-02/6.356e-02 (rms/max) Trust = 3.000e-01 (=) Grad = 1.707e-03/3.093e-03 (rms/max) E (change) = -228.8793574293 (-4.819e-05) Quality = 1.554
# Hessian Eigenvalues: 4.01400e-04 2.24980e-02 3.15070e-02 ... 5.34632e-01 8.04496e-01 1.16796e+00
# Step    9 : Displace = 8.688e-02/1.354e-01 (rms/max) Trust = 3.000e-01 (=) Grad = 2.168e-03/4.255e-03 (rms/max) E (change) = -228.8794321010 (-7.467e-05) Quality = 1.270
# Hessian Eigenvalues: 3.60950e-04 2.23301e-02 3.14216e-02 ... 5.27135e-01 8.01661e-01 1.05378e+00
# Step   10 : Displace = 3.917e-02/6.200e-02 (rms/max) Trust = 3.000e-01 (=) Grad = 1.357e-03/2.780e-03 (rms/max) E (change) = -228.8794796929 (-4.759e-05) Quality = 1.486
# Hessian Eigenvalues: 4.34180e-04 2.17265e-02 3.05193e-02 ... 4.89415e-01 6.92335e-01 8.14012e-01
# Step   11 : Displace = 1.159e-02/1.940e-02 (rms/max) Trust = 3.000e-01 (=) Grad = 1.338e-04/3.034e-04 (rms/max) E (change) = -228.8795033542 (-2.366e-05) Quality = 1.027
# Hessian Eigenvalues: 4.27403e-04 2.11236e-02 3.16911e-02 ... 4.85020e-01 7.12287e-01 8.17463e-01
# Step   12 : Displace = 2.917e-03/4.264e-03 (rms/max) Trust = 3.000e-01 (=) Grad = 4.297e-05/9.078e-05 (rms/max) E (change) = -228.8795037254 (-3.712e-07) Quality = 0.915
# Hessian Eigenvalues: 4.70401e-04 2.07889e-02 3.64266e-02 ... 4.83197e-01 7.08519e-01 8.23565e-01
# Step   13 : Displace = 1.209e-03/1.856e-03 (rms/max) Trust = 3.000e-01 (=) Grad = 1.435e-05/2.768e-05 (rms/max) E (change) = -228.8795037330 (-7.602e-09) Quality = 0.148
# Hessian Eigenvalues: 4.48112e-04 2.06275e-02 2.29065e-02 ... 4.86756e-01 7.13598e-01 8.31155e-01
# Step   14 : Displace = 5.703e-04/8.882e-04 (rms/max) Trust = 6.047e-04 (-) Grad = 2.064e-05/4.674e-05 (rms/max) E (change) = -228.8795037133 (+1.962e-08) Quality = -0.482
# Hessian Eigenvalues: 4.48112e-04 2.06275e-02 2.29065e-02 ... 4.86756e-01 7.13598e-01 8.31155e-01
# Converged! =D
#
#     #==========================================================================#
#     #| If this code has benefited your research, please support us by citing: |#
#     #|                                                                        |#
#     #| Wang, L.-P.; Song, C.C. (2016) "Geometry optimization made simple with |#
#     #| translation and rotation coordinates", J. Chem, Phys. 144, 214108.     |#
#     #| http://dx.doi.org/10.1063/1.4952956                                    |#
#     #==========================================================================#
#     Time elapsed since start of run_optimizer: 28.588 seconds
# geometric-optimize called with the following command line:
# /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/ipykernel_launcher.py -f /Users/mvondomaros/Library/Jupyter/runtime/kernel-560a9676-9c47-4ab6-b4dd-10595e1cfe53.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
#           ##      .%%%%%%/      (%%%%%%,                  ,******      /)))))
#         %%%%%%      .%%%%%%#      *%%%%%%,    ,/////.       ******      ))))))
#       #%      %%      .%%%%%%/      *%%%%%%,  ////////,      *****/     ,)))))
#     #%%  %%%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#   #%%%%.      %%%%%#      /%%%%%%*      #%%%%%%   /////)     ******      ))))),
#     #%%%%##%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#       ##     %%%      .%%%%%%/      *%%%%%%,  ////////.      *****/     ,)))))
#         #%%%%#      /%%%%%%/      (%%%%%%      /)/)//       ******      ))))))
#           ##      .%%%%%%/      (%%%%%%,                  *******      ))))))
#                 .%%%%%%/      *%%%%%%,  **.             /*******      .))))))
#               *%%%%%%/      (%%%%%%   ********/*..,*/*********       *))))))
#                 #%%/      (%%%%%%,    *********************/        )))))))
#                         *%%%%%%,         ,**************/         ,))))))/
#                       (%%%%%%   ()                              ))))))))
#                       #%%%%,  ())))))                        ,)))))))),
#                         #,    ())))))))))                ,)))))))))).
#                                  ()))))))))))))))))))))))))))))))/
#                                     ())))))))))))))))))))))))).
#                                          ())))))))))))))),
#
# -=#  geomeTRIC started. Version: 1.1  #=-
# Current date and time: 2026-01-30 14:59:17
# #========================================================#
# #|     Arguments passed to driver run_optimizer():      |#
# #========================================================#
# customengine              <pyscf.geomopt.geometric_solver.PySCFEngine object at 0x164091d10>
# input                     /var/folders/zr/f87d28w54h3djm8md3cct4300000gn/T/tmpym6ndw6k/079c36b7-29b8-4344-a4d9-86d045ff7af0
# logIni                    /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/pyscf/geomopt/log.ini
# maxiter                   100
# ----------------------------------------------------------
# Custom engine selected.
# Bonds will be generated from interatomic distances less than 1.20 times sum of covalent radii
# 21 internal coordinates being used (instead of 21 Cartesians)
# Internal coordinate system (atoms numbered from 1):
# Distance 1-2
# Distance 1-5
# Distance 1-6
# Distance 1-7
# Distance 2-3
# Distance 2-4
# Angle 2-1-5
# Angle 2-1-6
# Angle 2-1-7
# Angle 5-1-6
# Angle 5-1-7
# Angle 6-1-7
# Angle 1-2-4
# Angle 3-2-4
# Out-of-Plane 2-1-3-4
# Dihedral 5-1-2-3
# Dihedral 5-1-2-4
# Dihedral 6-1-2-3
# Dihedral 6-1-2-4
# Dihedral 7-1-2-3
# Dihedral 7-1-2-4
# Translation-X 1-7
# Translation-Y 1-7
# Translation-Z 1-7
# Rotation-A 1-7
# Rotation-B 1-7
# Rotation-C 1-7
# <class 'geometric.internal.Distance'> : 6
# <class 'geometric.internal.Angle'> : 8
# <class 'geometric.internal.OutOfPlane'> : 1
# <class 'geometric.internal.Dihedral'> : 6
# <class 'geometric.internal.TranslationX'> : 1
# <class 'geometric.internal.TranslationY'> : 1
# <class 'geometric.internal.TranslationZ'> : 1
# <class 'geometric.internal.RotationA'> : 1
# <class 'geometric.internal.RotationB'> : 1
# <class 'geometric.internal.RotationC'> : 1
# > ===== Optimization Info: ====
# > Job type: Energy minimization
# > Maximum number of optimization cycles: 100
# > Initial / maximum trust radius (Angstrom): 0.100 / 0.300
# > Convergence Criteria:
# > Will converge when all 5 criteria are reached:
# >  |Delta-E| < 1.00e-06
# >  RMS-Grad  < 3.00e-04
# >  Max-Grad  < 4.50e-04
# >  RMS-Disp  < 1.20e-03
# >  Max-Disp  < 1.80e-03
# > === End Optimization Info ===
# Step    0 : Gradient = 6.666e-02/1.390e-01 (rms/max) Energy = -228.2945652850
# Hessian Eigenvalues: 2.30000e-02 2.66910e-02 5.00000e-02 ... 3.53316e-01 5.11133e-01 8.02416e-01
# Step    1 : Displace = 6.165e-02/1.234e-01 (rms/max) Trust = 1.000e-01 (=) Grad = 1.495e-02/2.438e-02 (rms/max) E (change) = -228.3142291263 (-1.966e-02) Quality = 1.147
# Hessian Eigenvalues: 2.29935e-02 2.67139e-02 5.00000e-02 ... 3.50865e-01 4.57466e-01 8.09060e-01
# Step    2 : Displace = 8.001e-02/1.579e-01 (rms/max) Trust = 1.414e-01 (+) Grad = 1.952e-02/4.387e-02 (rms/max) E (change) = -228.3116244920 (+2.605e-03) Quality = -0.803
# Hessian Eigenvalues: 2.30008e-02 2.67430e-02 4.99999e-02 ... 4.50123e-01 8.05392e-01 8.65160e-01
# Step    3 : Displace = 4.035e-02/7.449e-02 (rms/max) Trust = 4.001e-02 (-) Grad = 3.674e-03/7.198e-03 (rms/max) E (change) = -228.3155232056 (-3.899e-03) Quality = 1.003
# Hessian Eigenvalues: 2.30013e-02 2.67332e-02 4.99999e-02 ... 4.47749e-01 8.03823e-01 8.60169e-01
# Step    4 : Displace = 1.384e-02/2.625e-02 (rms/max) Trust = 5.658e-02 (+) Grad = 1.718e-03/3.518e-03 (rms/max) E (change) = -228.3156956699 (-1.725e-04) Quality = 0.800
# Hessian Eigenvalues: 2.29973e-02 3.36649e-02 4.99991e-02 ... 4.77732e-01 7.62186e-01 8.28426e-01
# Step    5 : Displace = 5.694e-03/1.063e-02 (rms/max) Trust = 8.001e-02 (+) Grad = 1.450e-03/3.039e-03 (rms/max) E (change) = -228.3156980569 (-2.387e-06) Quality = 0.054
# Hessian Eigenvalues: 2.29972e-02 4.99945e-02 5.00000e-02 ... 4.42597e-01 7.94088e-01 8.05091e-01
# Step    6 : Displace = 3.026e-03/4.944e-03 (rms/max) Trust = 2.847e-03 (-) Grad = 3.910e-04/8.037e-04 (rms/max) E (change) = -228.3157204727 (-2.242e-05) Quality = 0.939
# Hessian Eigenvalues: 2.29974e-02 4.99913e-02 5.00000e-02 ... 4.62930e-01 7.87819e-01 8.41080e-01
# Step    7 : Displace = 7.600e-04/1.164e-03 (rms/max) Trust = 4.027e-03 (+) Grad = 1.790e-04/3.205e-04 (rms/max) E (change) = -228.3157214090 (-9.363e-07) Quality = 0.731
# Hessian Eigenvalues: 2.29974e-02 4.99913e-02 5.00000e-02 ... 4.62930e-01 7.87819e-01 8.41080e-01
# Converged! =D
#
#     #==========================================================================#
#     #| If this code has benefited your research, please support us by citing: |#
#     #|                                                                        |#
#     #| Wang, L.-P.; Song, C.C. (2016) "Geometry optimization made simple with |#
#     #| translation and rotation coordinates", J. Chem, Phys. 144, 214108.     |#
#     #| http://dx.doi.org/10.1063/1.4952956                                    |#
#     #==========================================================================#
#     Time elapsed since start of run_optimizer: 13.939 seconds
# geometric-optimize called with the following command line:
# /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/ipykernel_launcher.py -f /Users/mvondomaros/Library/Jupyter/runtime/kernel-560a9676-9c47-4ab6-b4dd-10595e1cfe53.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
#           ##      .%%%%%%/      (%%%%%%,                  ,******      /)))))
#         %%%%%%      .%%%%%%#      *%%%%%%,    ,/////.       ******      ))))))
#       #%      %%      .%%%%%%/      *%%%%%%,  ////////,      *****/     ,)))))
#     #%%  %%%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#   #%%%%.      %%%%%#      /%%%%%%*      #%%%%%%   /////)     ******      ))))),
#     #%%%%##%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#       ##     %%%      .%%%%%%/      *%%%%%%,  ////////.      *****/     ,)))))
#         #%%%%#      /%%%%%%/      (%%%%%%      /)/)//       ******      ))))))
#           ##      .%%%%%%/      (%%%%%%,                  *******      ))))))
#                 .%%%%%%/      *%%%%%%,  **.             /*******      .))))))
#               *%%%%%%/      (%%%%%%   ********/*..,*/*********       *))))))
#                 #%%/      (%%%%%%,    *********************/        )))))))
#                         *%%%%%%,         ,**************/         ,))))))/
#                       (%%%%%%   ()                              ))))))))
#                       #%%%%,  ())))))                        ,)))))))),
#                         #,    ())))))))))                ,)))))))))).
#                                  ()))))))))))))))))))))))))))))))/
#                                     ())))))))))))))))))))))))).
#                                          ())))))))))))))),
#
# -=#  geomeTRIC started. Version: 1.1  #=-
# Current date and time: 2026-01-30 14:59:58
# #========================================================#
# #|     Arguments passed to driver run_optimizer():      |#
# #========================================================#
# customengine              <pyscf.geomopt.geometric_solver.PySCFEngine object at 0x1640916d0>
# input                     /var/folders/zr/f87d28w54h3djm8md3cct4300000gn/T/tmp0xse2sxs/6bd2b084-4d7b-47d9-b018-2a7d5f63d91a
# logIni                    /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/pyscf/geomopt/log.ini
# maxiter                   100
# ----------------------------------------------------------
# Custom engine selected.
# Bonds will be generated from interatomic distances less than 1.20 times sum of covalent radii
# 9 internal coordinates being used (instead of 9 Cartesians)
# Internal coordinate system (atoms numbered from 1):
# Distance 1-2
# Distance 1-3
# Angle 2-1-3
# Translation-X 1-3
# Translation-Y 1-3
# Translation-Z 1-3
# Rotation-A 1-3
# Rotation-B 1-3
# Rotation-C 1-3
# <class 'geometric.internal.Distance'> : 2
# <class 'geometric.internal.Angle'> : 1
# <class 'geometric.internal.TranslationX'> : 1
# <class 'geometric.internal.TranslationY'> : 1
# <class 'geometric.internal.TranslationZ'> : 1
# <class 'geometric.internal.RotationA'> : 1
# <class 'geometric.internal.RotationB'> : 1
# <class 'geometric.internal.RotationC'> : 1
# > ===== Optimization Info: ====
# > Job type: Energy minimization
# > Maximum number of optimization cycles: 100
# > Initial / maximum trust radius (Angstrom): 0.100 / 0.300
# > Convergence Criteria:
# > Will converge when all 5 criteria are reached:
# >  |Delta-E| < 1.00e-06
# >  RMS-Grad  < 3.00e-04
# >  Max-Grad  < 4.50e-04
# >  RMS-Disp  < 1.20e-03
# >  Max-Disp  < 1.80e-03
# > === End Optimization Info ===
# Step    0 : Gradient = 2.124e-02/2.569e-02 (rms/max) Energy = -76.3553207515
# Hessian Eigenvalues: 5.00000e-02 5.00000e-02 5.00000e-02 ... 1.60000e-01 5.10090e-01 5.13374e-01
# Step    1 : Displace = 4.332e-02/5.150e-02 (rms/max) Trust = 1.000e-01 (=) Grad = 3.502e-03/3.937e-03 (rms/max) E (change) = -76.3572384906 (-1.918e-03) Quality = 0.958
# Hessian Eigenvalues: 5.00000e-02 5.00000e-02 5.00000e-02 ... 1.54754e-01 5.11749e-01 5.68582e-01
# Step    2 : Displace = 2.127e-03/2.462e-03 (rms/max) Trust = 1.414e-01 (+) Grad = 1.898e-04/2.713e-04 (rms/max) E (change) = -76.3572573687 (-1.888e-05) Quality = 1.002
# Hessian Eigenvalues: 4.99305e-02 5.00000e-02 5.00000e-02 ... 1.53213e-01 5.11783e-01 5.68171e-01
# Step    3 : Displace = 4.676e-04/4.774e-04 (rms/max) Trust = 2.000e-01 (+) Grad = 1.412e-05/1.910e-05 (rms/max) E (change) = -76.3572576296 (-2.610e-07) Quality = 1.156
# Hessian Eigenvalues: 4.99305e-02 5.00000e-02 5.00000e-02 ... 1.53213e-01 5.11783e-01 5.68171e-01
# Converged! =D
#
#     #==========================================================================#
#     #| If this code has benefited your research, please support us by citing: |#
#     #|                                                                        |#
#     #| Wang, L.-P.; Song, C.C. (2016) "Geometry optimization made simple with |#
#     #| translation and rotation coordinates", J. Chem, Phys. 144, 214108.     |#
#     #| http://dx.doi.org/10.1063/1.4952956                                    |#
#     #==========================================================================#
#     Time elapsed since start of run_optimizer: 1.309 seconds
# geometric-optimize called with the following command line:
# /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/ipykernel_launcher.py -f /Users/mvondomaros/Library/Jupyter/runtime/kernel-560a9676-9c47-4ab6-b4dd-10595e1cfe53.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
#           ##      .%%%%%%/      (%%%%%%,                  ,******      /)))))
#         %%%%%%      .%%%%%%#      *%%%%%%,    ,/////.       ******      ))))))
#       #%      %%      .%%%%%%/      *%%%%%%,  ////////,      *****/     ,)))))
#     #%%  %%%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#   #%%%%.      %%%%%#      /%%%%%%*      #%%%%%%   /////)     ******      ))))),
#     #%%%%##%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#       ##     %%%      .%%%%%%/      *%%%%%%,  ////////.      *****/     ,)))))
#         #%%%%#      /%%%%%%/      (%%%%%%      /)/)//       ******      ))))))
#           ##      .%%%%%%/      (%%%%%%,                  *******      ))))))
#                 .%%%%%%/      *%%%%%%,  **.             /*******      .))))))
#               *%%%%%%/      (%%%%%%   ********/*..,*/*********       *))))))
#                 #%%/      (%%%%%%,    *********************/        )))))))
#                         *%%%%%%,         ,**************/         ,))))))/
#                       (%%%%%%   ()                              ))))))))
#                       #%%%%,  ())))))                        ,)))))))),
#                         #,    ())))))))))                ,)))))))))).
#                                  ()))))))))))))))))))))))))))))))/
#                                     ())))))))))))))))))))))))).
#                                          ())))))))))))))),
#
# -=#  geomeTRIC started. Version: 1.1  #=-
# Current date and time: 2026-01-30 15:00:01
# #========================================================#
# #|     Arguments passed to driver run_optimizer():      |#
# #========================================================#
# customengine              <pyscf.geomopt.geometric_solver.PySCFEngine object at 0x1611bba80>
# input                     /var/folders/zr/f87d28w54h3djm8md3cct4300000gn/T/tmp96l4v_qi/45164128-2e41-4b89-beab-5ecd7e0a9640
# logIni                    /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/pyscf/geomopt/log.ini
# maxiter                   100
# ----------------------------------------------------------
# Custom engine selected.
# Bonds will be generated from interatomic distances less than 1.20 times sum of covalent radii
# 12 internal coordinates being used (instead of 12 Cartesians)
# Internal coordinate system (atoms numbered from 1):
# Distance 1-2
# Distance 1-3
# Distance 1-4
# Angle 2-1-3
# Angle 2-1-4
# Angle 3-1-4
# Translation-X 1-4
# Translation-Y 1-4
# Translation-Z 1-4
# Rotation-A 1-4
# Rotation-B 1-4
# Rotation-C 1-4
# <class 'geometric.internal.Distance'> : 3
# <class 'geometric.internal.Angle'> : 3
# <class 'geometric.internal.TranslationX'> : 1
# <class 'geometric.internal.TranslationY'> : 1
# <class 'geometric.internal.TranslationZ'> : 1
# <class 'geometric.internal.RotationA'> : 1
# <class 'geometric.internal.RotationB'> : 1
# <class 'geometric.internal.RotationC'> : 1
# > ===== Optimization Info: ====
# > Job type: Energy minimization
# > Maximum number of optimization cycles: 100
# > Initial / maximum trust radius (Angstrom): 0.100 / 0.300
# > Convergence Criteria:
# > Will converge when all 5 criteria are reached:
# >  |Delta-E| < 1.00e-06
# >  RMS-Grad  < 3.00e-04
# >  Max-Grad  < 4.50e-04
# >  RMS-Disp  < 1.20e-03
# >  Max-Disp  < 1.80e-03
# > === End Optimization Info ===
# Step    0 : Gradient = 1.337e-02/2.024e-02 (rms/max) Energy = -76.6293120511
# Hessian Eigenvalues: 5.00000e-02 5.00000e-02 5.00000e-02 ... 4.80156e-01 5.08614e-01 5.09497e-01
# Step    1 : Displace = 2.178e-02/2.546e-02 (rms/max) Trust = 1.000e-01 (=) Grad = 2.916e-03/4.706e-03 (rms/max) E (change) = -76.6302331004 (-9.210e-04) Quality = 1.230
# Hessian Eigenvalues: 4.99729e-02 5.00000e-02 5.00000e-02 ... 4.73688e-01 5.08315e-01 5.15308e-01
# Step    2 : Displace = 9.888e-03/1.491e-02 (rms/max) Trust = 1.414e-01 (+) Grad = 7.178e-04/1.148e-03 (rms/max) E (change) = -76.6303220834 (-8.898e-05) Quality = 1.139
# Hessian Eigenvalues: 4.96460e-02 5.00000e-02 5.00000e-02 ... 4.87174e-01 5.08772e-01 5.15123e-01
# Step    3 : Displace = 3.293e-03/5.192e-03 (rms/max) Trust = 2.000e-01 (+) Grad = 2.619e-04/4.066e-04 (rms/max) E (change) = -76.6303287733 (-6.690e-06) Quality = 1.131
# Hessian Eigenvalues: 4.60660e-02 4.99999e-02 5.00000e-02 ... 4.86912e-01 5.02768e-01 5.13026e-01
# Step    4 : Displace = 1.006e-03/1.490e-03 (rms/max) Trust = 2.828e-01 (+) Grad = 5.561e-05/8.465e-05 (rms/max) E (change) = -76.6303293200 (-5.468e-07) Quality = 0.781
# Hessian Eigenvalues: 4.60660e-02 4.99999e-02 5.00000e-02 ... 4.86912e-01 5.02768e-01 5.13026e-01
# Converged! =D
#
#     #==========================================================================#
#     #| If this code has benefited your research, please support us by citing: |#
#     #|                                                                        |#
#     #| Wang, L.-P.; Song, C.C. (2016) "Geometry optimization made simple with |#
#     #| translation and rotation coordinates", J. Chem, Phys. 144, 214108.     |#
#     #| http://dx.doi.org/10.1063/1.4952956                                    |#
#     #==========================================================================#
#     Time elapsed since start of run_optimizer: 2.294 seconds
# Gas phase: Δ_r G° = 758.86 kJ/mol
# Gas phase: K_rxn°  = 1.133e-133
# Gas phase: pK_rxn  = 132.95
# Gas phase: pKa ≈ 131.20

# %% [markdown]
# ## Including PCM water
#
# Now repeat the calculation with PCM water (`use_pcm=True`) and compute the same quantities.
#
# :::{admonition} Interpretation
# PCM is a continuum model and RRHO is an approximate treatment of molecular motion.
# For charged species, the absolute values are often less reliable than **differences** between related species.
# Use your results primarily for qualitative trends.
# :::

# %%
thermo_acoh_pcm = compute_thermo_for_molecule(acoh, T=T, P=P, use_pcm=True)
thermo_aco_pcm = compute_thermo_for_molecule(aco_minus, T=T, P=P, use_pcm=True)
thermo_h2o_pcm = compute_thermo_for_molecule(h2o, T=T, P=P, use_pcm=True)
thermo_h3o_pcm = compute_thermo_for_molecule(h3o_plus, T=T, P=P, use_pcm=True)

G_acoh_pcm, _ = thermo_acoh_pcm[G_key]
G_aco_pcm, _ = thermo_aco_pcm[G_key]
G_h2o_pcm, _ = thermo_h2o_pcm[G_key]
G_h3o_pcm, _ = thermo_h3o_pcm[G_key]

delta_G_pcm = (G_aco_pcm + G_h3o_pcm) - (G_acoh_pcm + G_h2o_pcm)
delta_G_pcm_kJmol = delta_G_pcm * hartree_to_kjmol

K_rxn_pcm = math.exp(-delta_G_pcm_kJmol / (R * T))
pK_rxn_pcm = -math.log10(K_rxn_pcm)
pKa_pcm = pK_rxn_pcm - math.log10(water_conc)

print(f"PCM water: Δ_r G° = {delta_G_pcm_kJmol:.2f} kJ/mol")
print(f"PCM water: K_rxn°  = {K_rxn_pcm:.3e}")
print(f"PCM water: pK_rxn  = {pK_rxn_pcm:.2f}")
print(f"PCM water: pKa ≈ {pKa_pcm:.2f}")
# Out:
# geometric-optimize called with the following command line:
# /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/ipykernel_launcher.py -f /Users/mvondomaros/Library/Jupyter/runtime/kernel-560a9676-9c47-4ab6-b4dd-10595e1cfe53.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
#           ##      .%%%%%%/      (%%%%%%,                  ,******      /)))))
#         %%%%%%      .%%%%%%#      *%%%%%%,    ,/////.       ******      ))))))
#       #%      %%      .%%%%%%/      *%%%%%%,  ////////,      *****/     ,)))))
#     #%%  %%%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#   #%%%%.      %%%%%#      /%%%%%%*      #%%%%%%   /////)     ******      ))))),
#     #%%%%##%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#       ##     %%%      .%%%%%%/      *%%%%%%,  ////////.      *****/     ,)))))
#         #%%%%#      /%%%%%%/      (%%%%%%      /)/)//       ******      ))))))
#           ##      .%%%%%%/      (%%%%%%,                  *******      ))))))
#                 .%%%%%%/      *%%%%%%,  **.             /*******      .))))))
#               *%%%%%%/      (%%%%%%   ********/*..,*/*********       *))))))
#                 #%%/      (%%%%%%,    *********************/        )))))))
#                         *%%%%%%,         ,**************/         ,))))))/
#                       (%%%%%%   ()                              ))))))))
#                       #%%%%,  ())))))                        ,)))))))),
#                         #,    ())))))))))                ,)))))))))).
#                                  ()))))))))))))))))))))))))))))))/
#                                     ())))))))))))))))))))))))).
#                                          ())))))))))))))),
#
# -=#  geomeTRIC started. Version: 1.1  #=-
# Current date and time: 2026-01-30 15:00:06
# #========================================================#
# #|     Arguments passed to driver run_optimizer():      |#
# #========================================================#
# customengine              <pyscf.geomopt.geometric_solver.PySCFEngine object at 0x1611bafd0>
# input                     /var/folders/zr/f87d28w54h3djm8md3cct4300000gn/T/tmptazm3m0m/7acec76a-78dc-43d2-8cfb-9488b01ec86a
# logIni                    /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/pyscf/geomopt/log.ini
# maxiter                   100
# ----------------------------------------------------------
# Custom engine selected.
# Bonds will be generated from interatomic distances less than 1.20 times sum of covalent radii
# 24 internal coordinates being used (instead of 24 Cartesians)
# Internal coordinate system (atoms numbered from 1):
# Distance 1-2
# Distance 1-5
# Distance 1-6
# Distance 1-7
# Distance 2-3
# Distance 2-4
# Distance 4-8
# Angle 2-1-5
# Angle 2-1-6
# Angle 2-1-7
# Angle 5-1-6
# Angle 5-1-7
# Angle 6-1-7
# Angle 1-2-4
# Angle 3-2-4
# Angle 2-4-8
# Out-of-Plane 2-1-3-4
# Dihedral 5-1-2-3
# Dihedral 5-1-2-4
# Dihedral 6-1-2-3
# Dihedral 6-1-2-4
# Dihedral 7-1-2-3
# Dihedral 7-1-2-4
# Dihedral 1-2-4-8
# Dihedral 3-2-4-8
# Translation-X 1-8
# Translation-Y 1-8
# Translation-Z 1-8
# Rotation-A 1-8
# Rotation-B 1-8
# Rotation-C 1-8
# <class 'geometric.internal.Distance'> : 7
# <class 'geometric.internal.Angle'> : 9
# <class 'geometric.internal.OutOfPlane'> : 1
# <class 'geometric.internal.Dihedral'> : 8
# <class 'geometric.internal.TranslationX'> : 1
# <class 'geometric.internal.TranslationY'> : 1
# <class 'geometric.internal.TranslationZ'> : 1
# <class 'geometric.internal.RotationA'> : 1
# <class 'geometric.internal.RotationB'> : 1
# <class 'geometric.internal.RotationC'> : 1
# > ===== Optimization Info: ====
# > Job type: Energy minimization
# > Maximum number of optimization cycles: 100
# > Initial / maximum trust radius (Angstrom): 0.100 / 0.300
# > Convergence Criteria:
# > Will converge when all 5 criteria are reached:
# >  |Delta-E| < 1.00e-06
# >  RMS-Grad  < 3.00e-04
# >  Max-Grad  < 4.50e-04
# >  RMS-Disp  < 1.20e-03
# >  Max-Disp  < 1.80e-03
# > === End Optimization Info ===
# Step    0 : Gradient = 5.610e-02/1.183e-01 (rms/max) Energy = -228.8621979866
# Hessian Eigenvalues: 2.30000e-02 2.30000e-02 2.58269e-02 ... 4.23171e-01 5.07698e-01 7.43264e-01
# Step    1 : Displace = 1.016e-01/1.687e-01 (rms/max) Trust = 1.000e-01 (=) Grad = 2.435e-02/4.951e-02 (rms/max) E (change) = -228.8798089831 (-1.761e-02) Quality = 0.936
# Hessian Eigenvalues: 2.22212e-02 2.30013e-02 2.58326e-02 ... 4.44238e-01 6.11320e-01 6.90272e-01
# Step    2 : Displace = 1.106e-01/1.855e-01 (rms/max) Trust = 1.414e-01 (+) Grad = 3.357e-02/5.798e-02 (rms/max) E (change) = -228.8828815000 (-3.073e-03) Quality = 0.285
# Hessian Eigenvalues: 1.53613e-02 2.30018e-02 2.58399e-02 ... 5.18306e-01 6.68525e-01 8.17427e-01
# Step    3 : Displace = 6.701e-02/1.065e-01 (rms/max) Trust = 1.414e-01 (=) Grad = 5.509e-03/1.331e-02 (rms/max) E (change) = -228.8903145631 (-7.433e-03) Quality = 1.013
# Hessian Eigenvalues: 1.52668e-02 2.30093e-02 2.58364e-02 ... 5.39142e-01 6.75844e-01 8.20576e-01
# Step    4 : Displace = 2.191e-02/3.206e-02 (rms/max) Trust = 2.000e-01 (+) Grad = 1.217e-03/1.814e-03 (rms/max) E (change) = -228.8906074937 (-2.929e-04) Quality = 0.950
# Hessian Eigenvalues: 1.45653e-02 2.26390e-02 2.59229e-02 ... 5.30265e-01 6.76510e-01 8.21764e-01
# Step    5 : Displace = 8.289e-03/1.531e-02 (rms/max) Trust = 2.828e-01 (+) Grad = 2.913e-04/3.919e-04 (rms/max) E (change) = -228.8906396374 (-3.214e-05) Quality = 0.939
# Hessian Eigenvalues: 1.53361e-02 2.14491e-02 2.82399e-02 ... 5.15152e-01 6.75703e-01 8.31003e-01
# Step    6 : Displace = 3.559e-03/5.039e-03 (rms/max) Trust = 3.000e-01 (+) Grad = 2.025e-04/3.533e-04 (rms/max) E (change) = -228.8906459346 (-6.297e-06) Quality = 1.528
# Hessian Eigenvalues: 4.92079e-03 1.74435e-02 3.43993e-02 ... 5.43477e-01 6.73590e-01 8.29620e-01
# Step    7 : Displace = 1.278e-02/1.985e-02 (rms/max) Trust = 3.000e-01 (=) Grad = 5.679e-04/9.261e-04 (rms/max) E (change) = -228.8906623345 (-1.640e-05) Quality = 1.460
# Hessian Eigenvalues: 1.39438e-03 1.98262e-02 3.44651e-02 ... 5.61855e-01 6.94595e-01 8.75771e-01
# Step    8 : Displace = 3.199e-02/4.935e-02 (rms/max) Trust = 3.000e-01 (=) Grad = 1.203e-03/1.889e-03 (rms/max) E (change) = -228.8906948535 (-3.252e-05) Quality = 1.450
# Hessian Eigenvalues: 5.39666e-04 1.96216e-02 3.77180e-02 ... 5.74305e-01 7.00667e-01 8.97738e-01
# Step    9 : Displace = 6.284e-02/9.830e-02 (rms/max) Trust = 3.000e-01 (=) Grad = 1.565e-03/2.733e-03 (rms/max) E (change) = -228.8907467549 (-5.190e-05) Quality = 1.306
# Hessian Eigenvalues: 3.64265e-04 2.04403e-02 3.73476e-02 ... 5.54096e-01 6.95201e-01 8.71713e-01
# Step   10 : Displace = 5.992e-02/9.400e-02 (rms/max) Trust = 3.000e-01 (=) Grad = 1.295e-03/2.320e-03 (rms/max) E (change) = -228.8908006067 (-5.385e-05) Quality = 1.360
# Hessian Eigenvalues: 3.86205e-04 1.85056e-02 3.45273e-02 ... 5.14389e-01 6.78750e-01 8.47817e-01
# Step   11 : Displace = 3.448e-02/5.440e-02 (rms/max) Trust = 3.000e-01 (=) Grad = 3.646e-04/7.399e-04 (rms/max) E (change) = -228.8908429786 (-4.237e-05) Quality = 1.167
# Hessian Eigenvalues: 4.20770e-04 1.67828e-02 3.51475e-02 ... 5.02931e-01 6.74004e-01 8.46717e-01
# Step   12 : Displace = 3.701e-03/5.568e-03 (rms/max) Trust = 3.000e-01 (=) Grad = 9.899e-05/2.055e-04 (rms/max) E (change) = -228.8908455631 (-2.585e-06) Quality = 0.926
# Hessian Eigenvalues: 4.18940e-04 1.90061e-02 3.44862e-02 ... 4.98885e-01 6.72582e-01 8.45766e-01
# Step   13 : Displace = 5.083e-04/8.303e-04 (rms/max) Trust = 3.000e-01 (=) Grad = 2.996e-05/4.844e-05 (rms/max) E (change) = -228.8908457206 (-1.575e-07) Quality = 0.794
# Hessian Eigenvalues: 4.18940e-04 1.90061e-02 3.44862e-02 ... 4.98885e-01 6.72582e-01 8.45766e-01
# Converged! =D
#
#     #==========================================================================#
#     #| If this code has benefited your research, please support us by citing: |#
#     #|                                                                        |#
#     #| Wang, L.-P.; Song, C.C. (2016) "Geometry optimization made simple with |#
#     #| translation and rotation coordinates", J. Chem, Phys. 144, 214108.     |#
#     #| http://dx.doi.org/10.1063/1.4952956                                    |#
#     #==========================================================================#
#     Time elapsed since start of run_optimizer: 62.718 seconds
# geometric-optimize called with the following command line:
# /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/ipykernel_launcher.py -f /Users/mvondomaros/Library/Jupyter/runtime/kernel-560a9676-9c47-4ab6-b4dd-10595e1cfe53.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
#           ##      .%%%%%%/      (%%%%%%,                  ,******      /)))))
#         %%%%%%      .%%%%%%#      *%%%%%%,    ,/////.       ******      ))))))
#       #%      %%      .%%%%%%/      *%%%%%%,  ////////,      *****/     ,)))))
#     #%%  %%%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#   #%%%%.      %%%%%#      /%%%%%%*      #%%%%%%   /////)     ******      ))))),
#     #%%%%##%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#       ##     %%%      .%%%%%%/      *%%%%%%,  ////////.      *****/     ,)))))
#         #%%%%#      /%%%%%%/      (%%%%%%      /)/)//       ******      ))))))
#           ##      .%%%%%%/      (%%%%%%,                  *******      ))))))
#                 .%%%%%%/      *%%%%%%,  **.             /*******      .))))))
#               *%%%%%%/      (%%%%%%   ********/*..,*/*********       *))))))
#                 #%%/      (%%%%%%,    *********************/        )))))))
#                         *%%%%%%,         ,**************/         ,))))))/
#                       (%%%%%%   ()                              ))))))))
#                       #%%%%,  ())))))                        ,)))))))),
#                         #,    ())))))))))                ,)))))))))).
#                                  ()))))))))))))))))))))))))))))))/
#                                     ())))))))))))))))))))))))).
#                                          ())))))))))))))),
#
# -=#  geomeTRIC started. Version: 1.1  #=-
# Current date and time: 2026-01-30 15:02:03
# #========================================================#
# #|     Arguments passed to driver run_optimizer():      |#
# #========================================================#
# customengine              <pyscf.geomopt.geometric_solver.PySCFEngine object at 0x166e11d90>
# input                     /var/folders/zr/f87d28w54h3djm8md3cct4300000gn/T/tmp2i7i39jn/c6b58c88-d734-4364-ba7d-be67259ff77d
# logIni                    /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/pyscf/geomopt/log.ini
# maxiter                   100
# ----------------------------------------------------------
# Custom engine selected.
# Bonds will be generated from interatomic distances less than 1.20 times sum of covalent radii
# 21 internal coordinates being used (instead of 21 Cartesians)
# Internal coordinate system (atoms numbered from 1):
# Distance 1-2
# Distance 1-5
# Distance 1-6
# Distance 1-7
# Distance 2-3
# Distance 2-4
# Angle 2-1-5
# Angle 2-1-6
# Angle 2-1-7
# Angle 5-1-6
# Angle 5-1-7
# Angle 6-1-7
# Angle 1-2-4
# Angle 3-2-4
# Out-of-Plane 2-1-3-4
# Dihedral 5-1-2-3
# Dihedral 5-1-2-4
# Dihedral 6-1-2-3
# Dihedral 6-1-2-4
# Dihedral 7-1-2-3
# Dihedral 7-1-2-4
# Translation-X 1-7
# Translation-Y 1-7
# Translation-Z 1-7
# Rotation-A 1-7
# Rotation-B 1-7
# Rotation-C 1-7
# <class 'geometric.internal.Distance'> : 6
# <class 'geometric.internal.Angle'> : 8
# <class 'geometric.internal.OutOfPlane'> : 1
# <class 'geometric.internal.Dihedral'> : 6
# <class 'geometric.internal.TranslationX'> : 1
# <class 'geometric.internal.TranslationY'> : 1
# <class 'geometric.internal.TranslationZ'> : 1
# <class 'geometric.internal.RotationA'> : 1
# <class 'geometric.internal.RotationB'> : 1
# <class 'geometric.internal.RotationC'> : 1
# > ===== Optimization Info: ====
# > Job type: Energy minimization
# > Maximum number of optimization cycles: 100
# > Initial / maximum trust radius (Angstrom): 0.100 / 0.300
# > Convergence Criteria:
# > Will converge when all 5 criteria are reached:
# >  |Delta-E| < 1.00e-06
# >  RMS-Grad  < 3.00e-04
# >  Max-Grad  < 4.50e-04
# >  RMS-Disp  < 1.20e-03
# >  Max-Disp  < 1.80e-03
# > === End Optimization Info ===
# Step    0 : Gradient = 5.586e-02/1.119e-01 (rms/max) Energy = -228.4095718799
# Hessian Eigenvalues: 2.30000e-02 2.66910e-02 5.00000e-02 ... 3.53316e-01 5.11133e-01 8.02416e-01
# Step    1 : Displace = 6.555e-02/1.299e-01 (rms/max) Trust = 1.000e-01 (=) Grad = 1.648e-02/3.690e-02 (rms/max) E (change) = -228.4243733727 (-1.480e-02) Quality = 1.218
# Hessian Eigenvalues: 2.29999e-02 2.67268e-02 4.99998e-02 ... 3.36252e-01 4.56115e-01 8.12144e-01
# Step    2 : Displace = 3.216e-02/6.118e-02 (rms/max) Trust = 1.414e-01 (+) Grad = 1.187e-02/2.252e-02 (rms/max) E (change) = -228.4241188217 (+2.546e-04) Quality = -0.155
# Hessian Eigenvalues: 2.29953e-02 2.67753e-02 4.99950e-02 ... 4.39641e-01 6.71143e-01 8.39222e-01
# Step    3 : Displace = 1.665e-02/3.582e-02 (rms/max) Trust = 1.608e-02 (-) Grad = 6.584e-03/1.347e-02 (rms/max) E (change) = -228.4251379006 (-1.019e-03) Quality = 0.939
# Hessian Eigenvalues: 2.29956e-02 2.67646e-02 4.99948e-02 ... 4.29543e-01 7.75831e-01 8.69987e-01
# Step    4 : Displace = 9.017e-03/1.748e-02 (rms/max) Trust = 2.274e-02 (+) Grad = 2.779e-03/5.176e-03 (rms/max) E (change) = -228.4253681018 (-2.302e-04) Quality = 0.782
# Hessian Eigenvalues: 2.29962e-02 2.94069e-02 4.99606e-02 ... 5.25152e-01 6.86269e-01 8.06329e-01
# Step    5 : Displace = 5.460e-03/8.307e-03 (rms/max) Trust = 3.216e-02 (+) Grad = 1.170e-03/2.387e-03 (rms/max) E (change) = -228.4253877834 (-1.968e-05) Quality = 0.384
# Hessian Eigenvalues: 2.29819e-02 4.56858e-02 4.98311e-02 ... 4.84740e-01 7.83680e-01 8.01651e-01
# Step    6 : Displace = 2.873e-03/5.215e-03 (rms/max) Trust = 3.216e-02 (=) Grad = 6.626e-04/1.249e-03 (rms/max) E (change) = -228.4254017124 (-1.393e-05) Quality = 0.793
# Hessian Eigenvalues: 2.29579e-02 4.92766e-02 4.99997e-02 ... 4.78436e-01 6.92893e-01 8.07242e-01
# Step    7 : Displace = 1.075e-03/1.651e-03 (rms/max) Trust = 4.549e-02 (+) Grad = 3.476e-04/7.434e-04 (rms/max) E (change) = -228.4254033087 (-1.596e-06) Quality = 0.548
# Hessian Eigenvalues: 2.28338e-02 4.69267e-02 4.99996e-02 ... 5.78690e-01 7.81916e-01 8.71946e-01
# Step    8 : Displace = 4.323e-04/8.063e-04 (rms/max) Trust = 4.549e-02 (=) Grad = 3.536e-05/5.528e-05 (rms/max) E (change) = -228.4254040209 (-7.122e-07) Quality = 1.122
# Hessian Eigenvalues: 2.28338e-02 4.69267e-02 4.99996e-02 ... 5.78690e-01 7.81916e-01 8.71946e-01
# Converged! =D
#
#     #==========================================================================#
#     #| If this code has benefited your research, please support us by citing: |#
#     #|                                                                        |#
#     #| Wang, L.-P.; Song, C.C. (2016) "Geometry optimization made simple with |#
#     #| translation and rotation coordinates", J. Chem, Phys. 144, 214108.     |#
#     #| http://dx.doi.org/10.1063/1.4952956                                    |#
#     #==========================================================================#
#     Time elapsed since start of run_optimizer: 32.869 seconds
# geometric-optimize called with the following command line:
# /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/ipykernel_launcher.py -f /Users/mvondomaros/Library/Jupyter/runtime/kernel-560a9676-9c47-4ab6-b4dd-10595e1cfe53.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
#           ##      .%%%%%%/      (%%%%%%,                  ,******      /)))))
#         %%%%%%      .%%%%%%#      *%%%%%%,    ,/////.       ******      ))))))
#       #%      %%      .%%%%%%/      *%%%%%%,  ////////,      *****/     ,)))))
#     #%%  %%%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#   #%%%%.      %%%%%#      /%%%%%%*      #%%%%%%   /////)     ******      ))))),
#     #%%%%##%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#       ##     %%%      .%%%%%%/      *%%%%%%,  ////////.      *****/     ,)))))
#         #%%%%#      /%%%%%%/      (%%%%%%      /)/)//       ******      ))))))
#           ##      .%%%%%%/      (%%%%%%,                  *******      ))))))
#                 .%%%%%%/      *%%%%%%,  **.             /*******      .))))))
#               *%%%%%%/      (%%%%%%   ********/*..,*/*********       *))))))
#                 #%%/      (%%%%%%,    *********************/        )))))))
#                         *%%%%%%,         ,**************/         ,))))))/
#                       (%%%%%%   ()                              ))))))))
#                       #%%%%,  ())))))                        ,)))))))),
#                         #,    ())))))))))                ,)))))))))).
#                                  ()))))))))))))))))))))))))))))))/
#                                     ())))))))))))))))))))))))).
#                                          ())))))))))))))),
#
# -=#  geomeTRIC started. Version: 1.1  #=-
# Current date and time: 2026-01-30 15:03:18
# #========================================================#
# #|     Arguments passed to driver run_optimizer():      |#
# #========================================================#
# customengine              <pyscf.geomopt.geometric_solver.PySCFEngine object at 0x16477bce0>
# input                     /var/folders/zr/f87d28w54h3djm8md3cct4300000gn/T/tmp9ahp15hm/16807c9f-7f12-42e5-80d4-3cd2f0f213e2
# logIni                    /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/pyscf/geomopt/log.ini
# maxiter                   100
# ----------------------------------------------------------
# Custom engine selected.
# Bonds will be generated from interatomic distances less than 1.20 times sum of covalent radii
# 9 internal coordinates being used (instead of 9 Cartesians)
# Internal coordinate system (atoms numbered from 1):
# Distance 1-2
# Distance 1-3
# Angle 2-1-3
# Translation-X 1-3
# Translation-Y 1-3
# Translation-Z 1-3
# Rotation-A 1-3
# Rotation-B 1-3
# Rotation-C 1-3
# <class 'geometric.internal.Distance'> : 2
# <class 'geometric.internal.Angle'> : 1
# <class 'geometric.internal.TranslationX'> : 1
# <class 'geometric.internal.TranslationY'> : 1
# <class 'geometric.internal.TranslationZ'> : 1
# <class 'geometric.internal.RotationA'> : 1
# <class 'geometric.internal.RotationB'> : 1
# <class 'geometric.internal.RotationC'> : 1
# > ===== Optimization Info: ====
# > Job type: Energy minimization
# > Maximum number of optimization cycles: 100
# > Initial / maximum trust radius (Angstrom): 0.100 / 0.300
# > Convergence Criteria:
# > Will converge when all 5 criteria are reached:
# >  |Delta-E| < 1.00e-06
# >  RMS-Grad  < 3.00e-04
# >  Max-Grad  < 4.50e-04
# >  RMS-Disp  < 1.20e-03
# >  Max-Disp  < 1.80e-03
# > === End Optimization Info ===
# Step    0 : Gradient = 1.880e-02/2.328e-02 (rms/max) Energy = -76.3652399462
# Hessian Eigenvalues: 5.00000e-02 5.00000e-02 5.00000e-02 ... 1.60000e-01 5.10090e-01 5.13374e-01
# Step    1 : Displace = 4.341e-02/5.107e-02 (rms/max) Trust = 1.000e-01 (=) Grad = 3.601e-03/4.644e-03 (rms/max) E (change) = -76.3671235237 (-1.884e-03) Quality = 1.011
# Hessian Eigenvalues: 5.00000e-02 5.00000e-02 5.00000e-02 ... 1.45839e-01 5.11755e-01 5.72801e-01
# Step    2 : Displace = 2.485e-03/3.448e-03 (rms/max) Trust = 1.414e-01 (+) Grad = 4.320e-04/5.978e-04 (rms/max) E (change) = -76.3671469409 (-2.342e-05) Quality = 1.135
# Hessian Eigenvalues: 4.98618e-02 5.00000e-02 5.00000e-02 ... 1.34663e-01 5.11774e-01 5.41345e-01
# Step    3 : Displace = 5.090e-04/6.300e-04 (rms/max) Trust = 2.000e-01 (+) Grad = 1.863e-05/1.967e-05 (rms/max) E (change) = -76.3671474111 (-4.702e-07) Quality = 1.031
# Hessian Eigenvalues: 4.98618e-02 5.00000e-02 5.00000e-02 ... 1.34663e-01 5.11774e-01 5.41345e-01
# Converged! =D
#
#     #==========================================================================#
#     #| If this code has benefited your research, please support us by citing: |#
#     #|                                                                        |#
#     #| Wang, L.-P.; Song, C.C. (2016) "Geometry optimization made simple with |#
#     #| translation and rotation coordinates", J. Chem, Phys. 144, 214108.     |#
#     #| http://dx.doi.org/10.1063/1.4952956                                    |#
#     #==========================================================================#
#     Time elapsed since start of run_optimizer: 2.048 seconds
# geometric-optimize called with the following command line:
# /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/ipykernel_launcher.py -f /Users/mvondomaros/Library/Jupyter/runtime/kernel-560a9676-9c47-4ab6-b4dd-10595e1cfe53.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
#           ##      .%%%%%%/      (%%%%%%,                  ,******      /)))))
#         %%%%%%      .%%%%%%#      *%%%%%%,    ,/////.       ******      ))))))
#       #%      %%      .%%%%%%/      *%%%%%%,  ////////,      *****/     ,)))))
#     #%%  %%%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#   #%%%%.      %%%%%#      /%%%%%%*      #%%%%%%   /////)     ******      ))))),
#     #%%%%##%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#       ##     %%%      .%%%%%%/      *%%%%%%,  ////////.      *****/     ,)))))
#         #%%%%#      /%%%%%%/      (%%%%%%      /)/)//       ******      ))))))
#           ##      .%%%%%%/      (%%%%%%,                  *******      ))))))
#                 .%%%%%%/      *%%%%%%,  **.             /*******      .))))))
#               *%%%%%%/      (%%%%%%   ********/*..,*/*********       *))))))
#                 #%%/      (%%%%%%,    *********************/        )))))))
#                         *%%%%%%,         ,**************/         ,))))))/
#                       (%%%%%%   ()                              ))))))))
#                       #%%%%,  ())))))                        ,)))))))),
#                         #,    ())))))))))                ,)))))))))).
#                                  ()))))))))))))))))))))))))))))))/
#                                     ())))))))))))))))))))))))).
#                                          ())))))))))))))),
#
# -=#  geomeTRIC started. Version: 1.1  #=-
# Current date and time: 2026-01-30 15:03:23
# #========================================================#
# #|     Arguments passed to driver run_optimizer():      |#
# #========================================================#
# customengine              <pyscf.geomopt.geometric_solver.PySCFEngine object at 0x166e69e10>
# input                     /var/folders/zr/f87d28w54h3djm8md3cct4300000gn/T/tmpzueu5uhm/09366485-ce09-446a-a06d-06a4275f9cbf
# logIni                    /Users/mvondomaros/Projects/ThermoLab/.pixi/envs/default/lib/python3.13/site-packages/pyscf/geomopt/log.ini
# maxiter                   100
# ----------------------------------------------------------
# Custom engine selected.
# Bonds will be generated from interatomic distances less than 1.20 times sum of covalent radii
# 12 internal coordinates being used (instead of 12 Cartesians)
# Internal coordinate system (atoms numbered from 1):
# Distance 1-2
# Distance 1-3
# Distance 1-4
# Angle 2-1-3
# Angle 2-1-4
# Angle 3-1-4
# Translation-X 1-4
# Translation-Y 1-4
# Translation-Z 1-4
# Rotation-A 1-4
# Rotation-B 1-4
# Rotation-C 1-4
# <class 'geometric.internal.Distance'> : 3
# <class 'geometric.internal.Angle'> : 3
# <class 'geometric.internal.TranslationX'> : 1
# <class 'geometric.internal.TranslationY'> : 1
# <class 'geometric.internal.TranslationZ'> : 1
# <class 'geometric.internal.RotationA'> : 1
# <class 'geometric.internal.RotationB'> : 1
# <class 'geometric.internal.RotationC'> : 1
# > ===== Optimization Info: ====
# > Job type: Energy minimization
# > Maximum number of optimization cycles: 100
# > Initial / maximum trust radius (Angstrom): 0.100 / 0.300
# > Convergence Criteria:
# > Will converge when all 5 criteria are reached:
# >  |Delta-E| < 1.00e-06
# >  RMS-Grad  < 3.00e-04
# >  Max-Grad  < 4.50e-04
# >  RMS-Disp  < 1.20e-03
# >  Max-Disp  < 1.80e-03
# > === End Optimization Info ===
# Step    0 : Gradient = 1.348e-02/1.881e-02 (rms/max) Energy = -76.7700107929
# Hessian Eigenvalues: 5.00000e-02 5.00000e-02 5.00000e-02 ... 4.80156e-01 5.08614e-01 5.09497e-01
# Step    1 : Displace = 2.133e-02/2.690e-02 (rms/max) Trust = 1.000e-01 (=) Grad = 2.103e-03/3.370e-03 (rms/max) E (change) = -76.7708703977 (-8.596e-04) Quality = 1.142
# Hessian Eigenvalues: 4.98973e-02 5.00000e-02 5.00000e-02 ... 4.89515e-01 5.09222e-01 5.37012e-01
# Step    2 : Displace = 5.402e-03/6.266e-03 (rms/max) Trust = 1.414e-01 (+) Grad = 5.245e-04/7.377e-04 (rms/max) E (change) = -76.7709044380 (-3.404e-05) Quality = 1.075
# Hessian Eigenvalues: 4.66416e-02 5.00000e-02 5.00000e-02 ... 4.96997e-01 5.08920e-01 5.32749e-01
# Step    3 : Displace = 7.869e-04/1.154e-03 (rms/max) Trust = 2.000e-01 (+) Grad = 1.449e-04/2.129e-04 (rms/max) E (change) = -76.7709067154 (-2.277e-06) Quality = 1.323
# Hessian Eigenvalues: 1.70022e-02 4.99999e-02 5.00000e-02 ... 4.97436e-01 5.09818e-01 6.03318e-01
# Step    4 : Displace = 9.378e-04/1.525e-03 (rms/max) Trust = 2.828e-01 (+) Grad = 3.862e-04/5.664e-04 (rms/max) E (change) = -76.7709092155 (-2.500e-06) Quality = 1.150
# Hessian Eigenvalues: 5.70398e-03 5.00000e-02 5.00000e-02 ... 4.97592e-01 5.09992e-01 7.71572e-01
# Step    5 : Displace = 9.717e-04/1.594e-03 (rms/max) Trust = 3.000e-01 (+) Grad = 7.636e-04/1.129e-03 (rms/max) E (change) = -76.7709123819 (-3.166e-06) Quality = 0.973
# Hessian Eigenvalues: 2.59814e-03 5.00000e-02 5.00000e-02 ... 4.97599e-01 5.10585e-01 8.15464e-01
# Step    6 : Displace = 5.051e-04/8.044e-04 (rms/max) Trust = 3.000e-01 (=) Grad = 9.360e-04/1.400e-03 (rms/max) E (change) = -76.7709159206 (-3.539e-06) Quality = 0.768
# Hessian Eigenvalues: 2.21117e-03 4.99999e-02 5.00001e-02 ... 4.97637e-01 5.10865e-01 7.03342e-01
# Step    7 : Displace = 7.747e-04/1.226e-03 (rms/max) Trust = 3.000e-01 (=) Grad = 6.038e-04/9.045e-04 (rms/max) E (change) = -76.7709188266 (-2.906e-06) Quality = 0.859
# Hessian Eigenvalues: 2.92902e-03 4.93065e-02 5.00000e-02 ... 4.97540e-01 5.07807e-01 5.39848e-01
# Step    8 : Displace = 1.266e-03/2.068e-03 (rms/max) Trust = 3.000e-01 (=) Grad = 7.675e-05/1.301e-04 (rms/max) E (change) = -76.7709206744 (-1.848e-06) Quality = 0.947
# Hessian Eigenvalues: 2.95866e-03 4.35757e-02 5.00001e-02 ... 4.97689e-01 5.05817e-01 5.47569e-01
# Step    9 : Displace = 2.595e-04/4.059e-04 (rms/max) Trust = 3.000e-01 (=) Grad = 4.393e-05/6.713e-05 (rms/max) E (change) = -76.7709207690 (-9.464e-08) Quality = 0.763
# Hessian Eigenvalues: 2.95866e-03 4.35757e-02 5.00001e-02 ... 4.97689e-01 5.05817e-01 5.47569e-01
# Converged! =D
#
#     #==========================================================================#
#     #| If this code has benefited your research, please support us by citing: |#
#     #|                                                                        |#
#     #| Wang, L.-P.; Song, C.C. (2016) "Geometry optimization made simple with |#
#     #| translation and rotation coordinates", J. Chem, Phys. 144, 214108.     |#
#     #| http://dx.doi.org/10.1063/1.4952956                                    |#
#     #==========================================================================#
#     Time elapsed since start of run_optimizer: 6.984 seconds
# PCM water: Δ_r G° = 161.75 kJ/mol
# PCM water: K_rxn°  = 4.597e-29
# PCM water: pK_rxn  = 28.34
# PCM water: pKa ≈ 26.59

# %% [markdown]
# ## Discussion
#
# In your report, address at least the following points:
#
# - How do the gas-phase and PCM reaction Gibbs free energies compare?
# - How do the corresponding equilibrium constants and estimated $\mathrm{pK_a}$ values compare to experimental
#   aqueous $\mathrm{pK_a}$ data for acetic acid?
# - Which approximations are likely to dominate the error?
#   - electronic structure method and basis set,
#   - RRHO treatment of vibrations and rotations,
#   - continuum solvation model (PCM),
#   - neglect of explicit solvent structure and activity effects.
# - What would you change if you needed a quantitatively reliable $\mathrm{pK_a}$ prediction?
